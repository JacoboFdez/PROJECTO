# %%
import requests
import pandas as pd
from time import sleep
import numpy as np
import re

from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options




import warnings
warnings.filterwarnings('ignore')

# %%
opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized')
opciones.add_argument('user.data-dir=selenium') 
opciones.add_argument('--incognito')

# %%
limite = 10000

# %%
lista_urls = []
for i in range(1, int(limite), 50):
    lista_urls.append(f"https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start={i}&ref_=adv_nxt")
    
driver = webdriver.Chrome(ChromeDriverManager().install())
data = driver.get("https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&ref_")
driver.implicitly_wait(3)
print("The current url is:"+str(driver.current_url))

driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a').click()
print("The current url is:"+str(driver.current_url))

try:        
    print("The current url is:"+str(driver.current_url))
    lista_url.append(str(driver.current_url))
    driver.find_element("xpath",'/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[1]/div[2]/a[2]').click()
except:
    pass

#driver.quit()
# Out:
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&ref_
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=51&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=51&ref_=adv_nxt

# %%
lista_urls = []
for i in range(1, int(limite), 50):
    lista_urls.append(f"https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start={i}&ref_=adv_nxt")

# %%
limite = 10000
limite
# Out:
# 10000

# %%
for i in range(1, int(limite), 50):
    print(i)
# Out:
# 1
# 51
# 101
# 151
# 201
# 251
# 301
# 351
# 401
# 451
# 501
# 551
# 601
# 651
# 701
# 751
# 801
# 851
# 901
# 951
# 1001
# 1051
# 1101
# 1151
# 1201
# 1251
# 1301
# 1351
# 1401
# 1451
# 1501
# 1551
# 1601
# 1651
# 1701
# 1751
# 1801
# 1851
# 1901
# 1951
# 2001
# 2051
# 2101
# 2151
# 2201
# 2251
# 2301
# 2351
# 2401
# 2451
# 2501
# 2551
# 2601
# 2651
# 2701
# 2751
# 2801
# 2851
# 2901
# 2951
# 3001
# 3051
# 3101
# 3151
# 3201
# 3251
# 3301
# 3351
# 3401
# 3451
# 3501
# 3551
# 3601
# 3651
# 3701
# 3751
# 3801
# 3851
# 3901
# 3951
# 4001
# 4051
# 4101
# 4151
# 4201
# 4251
# 4301
# 4351
# 4401
# 4451
# 4501
# 4551
# 4601
# 4651
# 4701
# 4751
# 4801
# 4851
# 4901
# 4951
# 5001
# 5051
# 5101
# 5151
# 5201
# 5251
# 5301
# 5351
# 5401
# 5451
# 5501
# 5551
# 5601
# 5651
# 5701
# 5751
# 5801
# 5851
# 5901
# 5951
# 6001
# 6051
# 6101
# 6151
# 6201
# 6251
# 6301
# 6351
# 6401
# 6451
# 6501
# 6551
# 6601
# 6651
# 6701
# 6751
# 6801
# 6851
# 6901
# 6951
# 7001
# 7051
://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&ref_")
driver.implicitly_wait(3)
print("The current url is:"+str(driver.current_url))

driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a').click()
print("The current url is:"+str(driver.current_url))

try:        
    print("The current url is:"+str(driver.current_url))
    lista_url.append(str(driver.current_url))
    driver.find_element("xpath",'/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[1]/div[2]/a[2]').click()
except:
    pass

# %%
diccionario = {"titulo":[],
              "rating":[],
              "genre":[]}

# %%
url = "https://www.imdb.com/search/title/?sort=user_rating,desc&title_type=game"

# %%
#main > div > div.nav > div.desc > a.lister-page-next.next-page

# %%
result_list = []

for i in lista_urls[:3]: 
    driver.get(i)
    try:
        sleep(5)
        driver.find_element_by_css_selector('#truste-consent-button').click()
        sleep(2)
        resultado = driver.find_element_by_css_selector("#inner-content > div.region-content-main > div.row > div:nth-child(5) > div:nth-child(1) > div > lib-city-history-observation > div > div.observation-table.ng-star-inserted").text
        result_list.append(resultado)
    except: 
        sleep(5)
        resultado = driver.find_element_by_css_selector("#inner-content > div.region-content-main > div.row > div:nth-child(5) > div:nth-child(1) > div > lib-city-history-observation > div > div.observation-table.ng-star-inserted").text
        result_list.append(resultado)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [18], line 7
#       6 sleep(5)
# ----> 7 driver.find_element_by_css_selector('#truste-consent-button').click()
#       8 sleep(2)
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_css_selector'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [18], line 13
#      11     except:
#      12         sleep(5)
# ---> 13         resultado = driver.find_element_by_css_selector("#inner-content > div.region-content-main > div.row > div:nth-child(5) > div:nth-child(1) > div > lib-city-history-observation > div > div.observation-table.ng-star-inserted").text
#      14         result_list.append(resultado)
#      15 driver.quit()
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_css_selector'

# %%
lista_url
# Out:
# ['https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=51&ref_=adv_nxt']

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
data = driver.get("https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&ref_")
driver.implicitly_wait(3)
print("The current url is:"+str(driver.current_url))

driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
driver.implicitly_wait(3)
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
driver.implicitly_wait(2)
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))
driver.implicitly_wait(3)
driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
print("The current url is:"+str(driver.current_url))

try:        
    print("The current url is:"+str(driver.current_url))
    lista_url.append(str(driver.current_url))
    driver.find_element("xpath",'//*[@id="main"]/div/div[1]/div[2]/a[2]').click()
except:
    pass
# Out:
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&ref_
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=51&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=101&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=151&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=201&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=151&ref_=adv_prv
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=201&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=251&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=301&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=251&ref_=adv_prv
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=301&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=351&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=401&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=351&ref_=adv_prv
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=401&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=451&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=501&ref_=adv_nxt
# The current url is:https://www.imdb.com/search/title/?title_type=video_game&sort=user_rating,desc&start=501&ref_=adv_nxt

# %%
//*[@id="main"]/div/div[1]/div[2]/a[2]
//*[@id="main"]/div/div[1]/div[2]/a[2]
//*[@id="main"]/div/div[1]/div[2]/a[2]
